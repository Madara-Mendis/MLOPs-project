# %%
import os

# %%
os.chdir("../")

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class ModelTrainerConfig:
    root_dir: Path
    train_data_path: Path
    test_data_path: Path
    model_name: str
    alpha: float
    l1_ratio: float
    target_column: str

# %%
from MLOpsProject.constants import *
from MLOpsProject.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])


    def get_model_trainer_config(self) -> ModelTrainerConfig:
        config = self.config.model_trainer
        params = self.params.ElasticNet
        schema =  self.schema.TARGET_COLUMN

        create_directories([config.root_dir])

        model_trainer_config = ModelTrainerConfig(
            root_dir=config.root_dir,
            train_data_path = config.train_data_path,
            test_data_path = config.test_data_path,
            model_name = config.model_name,
            alpha = params.alpha,
            l1_ratio = params.l1_ratio,
            target_column = schema.name
            
        )

        return model_trainer_config

# %%
import pandas as pd
import os
from MLOpsProject import logger
from sklearn.linear_model import ElasticNet
import joblib

# %%
class ModelTrainer:
    def __init__(self, config: ModelTrainerConfig):
        self.config = config

    
    def train(self):
        train_data = pd.read_csv(self.config.train_data_path)
        test_data = pd.read_csv(self.config.test_data_path)


        train_x = train_data.drop([self.config.target_column], axis=1)
        test_x = test_data.drop([self.config.target_column], axis=1)
        train_y = train_data[[self.config.target_column]]
        test_y = test_data[[self.config.target_column]]


        lr = ElasticNet(alpha=self.config.alpha, l1_ratio=self.config.l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        joblib.dump(lr, os.path.join(self.config.root_dir, self.config.model_name))

# %%
try:
    config = ConfigurationManager()
    model_trainer_config = config.get_model_trainer_config()
    model_trainer_config = ModelTrainer(config=model_trainer_config)
    model_trainer_config.train()
except Exception as e:
    raise e
# Out:
# 2025-11-29 21:23:09,267 : INFO : common : YAML file: config\config.yaml loaded successfully
# 2025-11-29 21:23:09,271 : INFO : common : YAML file: params.yaml loaded successfully
# 2025-11-29 21:23:09,277 : INFO : common : YAML file: schema.yaml loaded successfully
# 2025-11-29 21:23:09,280 : INFO : common : Directory created at: artifacts
# 2025-11-29 21:23:09,281 : INFO : common : Directory created at: artifacts/model_trainer

# %% [markdown]
# ## Model Evaluation

# %%
os.environ["MLFLOW_TRACKING_URI"]="https://dagshub.com/madara.21/MLOPs-project.mlflow"
os.environ["MLFLOW_TRACKING_USERNAME"]="madara.21"
os.environ["MLFLOW_TRACKING_PASSWORD"]="e3bc836e7b5dfad84f110580499725ecd5d613cd"

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class ModelEvaluationConfig:
    root_dir: Path
    test_data_path: Path
    model_path: Path
    all_params: dict
    metric_file_name: Path
    target_column: str
    mlflow_uri: str

# %%
from MLOpsProject.constants import *
from MLOpsProject.utils.common import read_yaml, create_directories, save_json

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    
    def get_model_evaluation_config(self) -> ModelEvaluationConfig:
        config = self.config.model_evaluation
        params = self.params.ElasticNet
        schema =  self.schema.TARGET_COLUMN

        create_directories([config.root_dir])

        model_evaluation_config = ModelEvaluationConfig(
            root_dir=config.root_dir,
            test_data_path=config.test_data_path,
            model_path = config.model_path,
            all_params=params,
            metric_file_name = config.metric_file_name,
            target_column = schema.name,
            mlflow_uri="https://dagshub.com/madara.21/MLOPs-project.mlflow",
           
        )

        return model_evaluation_config

# %%
import os
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from urllib.parse import urlparse
import mlflow
import mlflow.sklearn
import numpy as np
import joblib

# %%
class ModelEvaluation:
    def __init__(self, config: ModelEvaluationConfig):
        self.config = config

    
    def eval_metrics(self,actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        mae = mean_absolute_error(actual, pred)
        r2 = r2_score(actual, pred)
        return rmse, mae, r2
    


    def log_into_mlflow(self):

        test_data = pd.read_csv(self.config.test_data_path)
        model = joblib.load(self.config.model_path)

        test_x = test_data.drop([self.config.target_column], axis=1)
        test_y = test_data[[self.config.target_column]]


        mlflow.set_registry_uri(self.config.mlflow_uri)
        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme


        with mlflow.start_run():

            predicted_qualities = model.predict(test_x)

            (rmse, mae, r2) = self.eval_metrics(test_y, predicted_qualities)
            
            # Saving metrics as local
            scores = {"rmse": rmse, "mae": mae, "r2": r2}
            save_json(path=Path(self.config.metric_file_name), data=scores)

            mlflow.log_params(self.config.all_params)

            mlflow.log_metric("rmse", rmse)
            mlflow.log_metric("r2", r2)
            mlflow.log_metric("mae", mae)


            # Model registry does not work with file store
            if tracking_url_type_store != "file":

                # Register the model
                # There are other ways to use the Model Registry, which depends on the use case,
                # please refer to the doc for more information:
                # https://mlflow.org/docs/latest/model-registry.html#api-workflow
                mlflow.sklearn.log_model(model, "model", registered_model_name="ElasticnetModel")
            else:
                mlflow.sklearn.log_model(model, "model")

# %%
try:
    config = ConfigurationManager()
    model_evaluation_config = config.get_model_evaluation_config()
    model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
    model_evaluation_config.log_into_mlflow()
except Exception as e:
    raise e
# Out:
# 2025-11-29 22:49:47,402 : INFO : common : YAML file: config\config.yaml loaded successfully
# 2025-11-29 22:49:47,412 : INFO : common : YAML file: params.yaml loaded successfully
# 2025-11-29 22:49:47,415 : INFO : common : YAML file: schema.yaml loaded successfully
# 2025-11-29 22:49:47,416 : INFO : common : Directory created at: artifacts
# 2025-11-29 22:49:47,417 : INFO : common : Directory created at: artifacts/model_evaluation
# 2025-11-29 22:49:48,425 : INFO : common : JSON file saved at: artifacts\model_evaluation\metrics.json
# 2025/11/29 22:49:49 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run serious-hen-797 at: https://dagshub.com/madara.21/MLOPs-project.mlflow/#/experiments/0/runs/4a46608310574c3ca0044d8c1bfdef78
# 🧪 View experiment at: https://dagshub.com/madara.21/MLOPs-project.mlflow/#/experiments/0
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[29], line 7
#       5     model_evaluation_config.log_into_mlflow()
#       6 except Exception as e:
# ----> 7     raise e
#
# Cell In[29], line 5
#       3     model_evaluation_config = config.get_model_evaluation_config()
#       4     model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
# ----> 5     model_evaluation_config.log_into_mlflow()
#       6 except Exception as e:
#       7     raise e
#
# Cell In[28], line 51, in ModelEvaluation.log_into_mlflow(self)
#      44 # Model registry does not work with file store
#      45 if tracking_url_type_store != "file":
#      46
#      47     # Register the model
#      48     # There are other ways to use the Model Registry, which depends on the use case,
#      49     # please refer to the doc for more information:
#      50     # https://mlflow.org/docs/latest/model-registry.html#api-workflow
# ---> 51     mlflow.sklearn.log_model(model, "model", registered_model_name="ElasticnetModel")
#      52 else:
#      53     mlflow.sklearn.log_model(model, "model")
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\sklearn\__init__.py:426, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)    355     name: str | None = None,
#     356 ):
#     357     """
#     358     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     359     containing the following flavors:
#    (...)    424
#     425     """
# --> 426     return Model.log(
#     427         artifact_path=artifact_path,
#     428         name=name,
#     429         flavor=mlflow.sklearn,
#     430         sk_model=sk_model,
#     431         conda_env=conda_env,
#     432         code_paths=code_paths,
#     433         serialization_format=serialization_format,
#     434         registered_model_name=registered_model_name,
#     435         signature=signature,
#     436         input_example=input_example,
#     437         await_registration_for=await_registration_for,
#     438         pip_requirements=pip_requirements,
#     439         extra_pip_requirements=extra_pip_requirements,
#     440         pyfunc_predict_fn=pyfunc_predict_fn,
#     441         metadata=metadata,
#     442         params=params,
#     443         tags=tags,
#     444         model_type=model_type,
#     445         step=step,
#     446         model_id=model_id,
#     447     )
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\models\model.py:1165, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1163 if flavor_name is None:
#    1164     flavor_name = flavor.__name__ if hasattr(flavor, "__name__") else "custom"
# -> 1165 model = _create_logged_model(
#    1166     # TODO: Update model name
#    1167     name=name,
#    1168     source_run_id=run_id,
#    1169     model_type=model_type,
#    1170     params={key: str(value) for key, value in params.items()},
#    1171     tags={key: str(value) for key, value in tags.items()}
#    1172     if tags is not None
#    1173     else None,
#    1174     flavor=flavor_name,
#    1175 )
#    1176 _last_logged_model_id.set(model.model_id)
#    1177 if (
#    1178     MLFLOW_PRINT_MODEL_URLS_ON_CREATION.get()
#    1179     and is_databricks_uri(tracking_uri)
#    1180     and (workspace_url := get_workspace_url())
#    1181 ):
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\tracking\fluent.py:2330, in _create_logged_model(name, source_run_id, tags, params, model_type, experiment_id, flavor)
#    2326     experiment_id = _get_experiment_id() or (
#    2327         get_run(source_run_id).info.experiment_id if source_run_id else None
#    2328     )
#    2329 resolved_tags = context_registry.resolve_tags(tags)
# -> 2330 return MlflowClient()._create_logged_model(
#    2331     experiment_id=experiment_id,
#    2332     name=name,
#    2333     source_run_id=source_run_id,
#    2334     tags=resolved_tags,
#    2335     params=params,
#    2336     model_type=model_type,
#    2337     flavor=flavor,
#    2338 )
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\tracking\client.py:5500, in MlflowClient._create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type, flavor)
#    5490 def _create_logged_model(
#    5491     self,
#    5492     experiment_id: str,
#    (...)   5498     flavor: str | None = None,
#    5499 ) -> LoggedModel:
# -> 5500     return self._tracking_client.create_logged_model(
#    5501         experiment_id, name, source_run_id, tags, params, model_type, flavor
#    5502     )
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\telemetry\track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:870, in TrackingServiceClient.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type, flavor)
#     857 @record_usage_event(CreateLoggedModelEvent)
#     858 def create_logged_model(
#     859     self,
#    (...)    868     flavor: str | None = None,
#     869 ) -> LoggedModel:
# --> 870     return self.store.create_logged_model(
#     871         experiment_id=experiment_id,
#     872         name=name,
#     873         source_run_id=source_run_id,
#     874         tags=[LoggedModelTag(str(key), str(value)) for key, value in tags.items()]
#     875         if tags is not None
#     876         else tags,
#     877         params=[LoggedModelParameter(str(key), str(value)) for key, value in params.items()]
#     878         if params is not None
#     879         else params,
#     880         model_type=model_type,
#     881     )
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\store\tracking\rest_store.py:932, in RestStore.create_logged_model(self, experiment_id, name, source_run_id, tags, params, model_type)
#     919     remaining_params = params[initial_batch_size:]
#     921 req_body = message_to_json(
#     922     CreateLoggedModel(
#     923         experiment_id=experiment_id,
#    (...)    929     )
#     930 )
# --> 932 response_proto = self._call_endpoint(CreateLoggedModel, req_body)
#     933 model = LoggedModel.from_proto(response_proto.model)
#     935 # Log remaining params if there are any
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\store\tracking\rest_store.py:203, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     201     endpoint, method = self._METHOD_TO_INFO[api]
#     202 response_proto = response_proto or api.Response()
# --> 203 return call_endpoint(
#     204     self.get_host_creds(),
#     205     endpoint,
#     206     method,
#     207     json_body,
#     208     response_proto,
#     209     retry_timeout_seconds=retry_timeout_seconds,
#     210 )
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\utils\rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File c:\Users\MadaraMendis\anaconda3\envs\mlopsp\Lib\site-packages\mlflow\utils\rest_utils.py:315, in verify_rest_response(response, endpoint)
#     313 if response.status_code != 200:
#     314     if _can_parse_as_json_object(response.text):
# --> 315         raise RestException(json.loads(response.text))
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
#
# RestException: INTERNAL_ERROR: Response: {'error': 'unsupported endpoint, please contact support@dagshub.com'}
